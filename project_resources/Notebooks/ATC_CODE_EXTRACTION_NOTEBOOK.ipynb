# %% [markdown]
# # ATC_CODE_EXTRACTION_NOTEBOOK

# %%
import pandas as pd

# Read the Excel file
df_antimicrobials = pd.read_excel('C:\\Personal_Projects\\Astro\\project_resources\\Antimicrobials.xlsx', sheet_name='Sheet1')

# Display the first 5 rows
df_antimicrobials.head()
# Out:
#    ATC_CODE WHONET_CODE        ANTIMICROBIAL  ANTIMICROBIAL_CLASS  \
# 0       NaN         FCT     5-Fluorocytosine                  NaN
# 1       NaN         ACM    Acetylmidecamycin                  NaN
# 2       NaN         ASP     Acetylspiramycin                  NaN
# 3       NaN         AMK             Amikacin                  NaN
# 4       NaN         AKF  Amikacin/Fosfomycin                  NaN
#
#    WHO_AWARE_CLASSIFICATION
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
# Check dataset size and sample more data
print(f"Total antimicrobials: {len(df_antimicrobials)}")
print("\nSample of antimicrobial names:")
print(df_antimicrobials['ANTIMICROBIAL'].head(10).tolist())
print("\nLast 5 entries:")
print(df_antimicrobials['ANTIMICROBIAL'].tail(5).tolist())
# Out:
# Total antimicrobials: 392
#
# Sample of antimicrobial names:
# ['5-Fluorocytosine', 'Acetylmidecamycin', 'Acetylspiramycin', 'Amikacin', 'Amikacin/Fosfomycin', 'Amoxicillin', 'Amoxicillin/Clavulanic acid', 'Amoxicillin/Sulbactam', 'Amphotericin B', 'Ampicillin']
#
# Last 5 entries:
# ['Viomycin', 'Virginiamycine', 'Voriconazole', 'Zidebactam', 'Zoliflodacin']

# %%
# Install required packages for web scraping
import requests
from bs4 import BeautifulSoup
import time
import re
from urllib.parse import quote_plus
import json

# Function to search for ATC codes from WHO website
def get_atc_code_from_who(antimicrobial_name):
    """
    Search for ATC code of an antimicrobial from WHO ATC/DDD Index website
    """
    try:
        # Clean the antimicrobial name for search
        # Remove combination indicators and special characters
        search_name = antimicrobial_name.split('/')[0]  # Take first part if combination
        search_name = re.sub(r'[^a-zA-Z\s]', '', search_name).strip()
        
        # WHO ATC/DDD Index search URL
        base_url = "https://www.whocc.no/atc_ddd_index/"
        search_url = f"https://www.whocc.no/atc_ddd_index/?code=&name={quote_plus(search_name)}"
        
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        
        response = requests.get(search_url, headers=headers, timeout=10)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Look for ATC codes in the search results
        # ATC codes typically follow pattern: 1-2 letters + 2 digits + 2 letters + 2 digits
        atc_pattern = r'[A-Z]{1,2}\d{2}[A-Z]{2}\d{2}'
        
        # Search in table rows or result divs
        tables = soup.find_all('table')
        for table in tables:
            rows = table.find_all('tr')
            for row in rows:
                row_text = row.get_text()
                if search_name.lower() in row_text.lower():
                    atc_matches = re.findall(atc_pattern, row_text)
                    if atc_matches:
                        return atc_matches[0]  # Return first match
        
        # If no table results, search in general page content
        page_text = soup.get_text()
        if search_name.lower() in page_text.lower():
            atc_matches = re.findall(atc_pattern, page_text)
            if atc_matches:
                return atc_matches[0]
        
        return None
        
    except Exception as e:
        print(f"Error searching for {antimicrobial_name}: {str(e)}")
        return None

print("ATC code lookup function created!")
# Out:
# ATC code lookup function created!

# %%
# Test the function with a few known antimicrobials
test_antimicrobials = ['Amoxicillin', 'Ampicillin', 'Ciprofloxacin', 'Penicillin']

print("Testing ATC code lookup:")
for antimicrobial in test_antimicrobials:
    atc_code = get_atc_code_from_who(antimicrobial)
    print(f"{antimicrobial}: {atc_code}")
    time.sleep(1)  # Be respectful to the server
# Out:
# Testing ATC code lookup:
# Amoxicillin: J01CA04
# Ampicillin: J01CA01
# Ciprofloxacin: J01MA02
# Penicillin: J01RA01

# %%
# Improved function with better error handling and caching
def get_atc_codes_batch(antimicrobials_list, delay=1.5):
    """
    Get ATC codes for a list of antimicrobials with progress tracking
    """
    results = {}
    total = len(antimicrobials_list)
    
    for i, antimicrobial in enumerate(antimicrobials_list, 1):
        print(f"Processing {i}/{total}: {antimicrobial}")
        
        # Skip if already processed
        if antimicrobial in results:
            continue
            
        atc_code = get_atc_code_from_who(antimicrobial)
        results[antimicrobial] = atc_code
        
        # Print result
        if atc_code:
            print(f"  ✓ Found: {atc_code}")
        else:
            print(f"  ✗ Not found")
            
        # Be respectful to the server
        if i < total:
            time.sleep(delay)
    
    return results

print("Batch processing function created!")
# Out:
# Batch processing function created!

# %%
# Test with first 10 antimicrobials
test_antimicrobials_list = df_antimicrobials['ANTIMICROBIAL'].head(10).tolist()
print("Testing with first 10 antimicrobials:")
for i, name in enumerate(test_antimicrobials_list, 1):
    print(f"{i}. {name}")

print("\nStarting batch processing...")
test_results = get_atc_codes_batch(test_antimicrobials_list, delay=1.0)

print("\n=== TEST RESULTS ===")
for antimicrobial, atc_code in test_results.items():
    status = atc_code if atc_code else 'NOT FOUND'
    print(f"{antimicrobial}: {status}")
# Out:
# Testing with first 10 antimicrobials:
# 1. 5-Fluorocytosine
# 2. Acetylmidecamycin
# 3. Acetylspiramycin
# 4. Amikacin
# 5. Amikacin/Fosfomycin
# 6. Amoxicillin
# 7. Amoxicillin/Clavulanic acid
# 8. Amoxicillin/Sulbactam
# 9. Amphotericin B
# 10. Ampicillin
#
# Starting batch processing...
# Processing 1/10: 5-Fluorocytosine
#   ✗ Not found
# Processing 2/10: Acetylmidecamycin
#   ✗ Not found
# Processing 3/10: Acetylspiramycin
#   ✗ Not found
# Processing 4/10: Amikacin
#   ✓ Found: D06AX12
# Processing 5/10: Amikacin/Fosfomycin
#   ✓ Found: D06AX12
# Processing 6/10: Amoxicillin
#   ✓ Found: J01CA04
# Processing 7/10: Amoxicillin/Clavulanic acid
#   ✓ Found: J01CA04
# Processing 8/10: Amoxicillin/Sulbactam
#   ✓ Found: J01CA04
# Processing 9/10: Amphotericin B
#   ✓ Found: A01AB04
# Processing 10/10: Ampicillin
#   ✓ Found: J01CA01
#
# === TEST RESULTS ===
# 5-Fluorocytosine: NOT FOUND
# Acetylmidecamycin: NOT FOUND
# Acetylspiramycin: NOT FOUND
# Amikacin: D06AX12
# Amikacin/Fosfomycin: D06AX12
# Amoxicillin: J01CA04
# Amoxicillin/Clavulanic acid: J01CA04
# Amoxicillin/Sulbactam: J01CA04
# Amphotericin B: A01AB04
# Ampicillin: J01CA01

# %%
# Process all antimicrobials
print(f"\nProcessing all {len(df_antimicrobials)} antimicrobials...")
print("This will take approximately 8-10 minutes with respectful delays.")
print("Note: Some antimicrobials may not be found as they might be:")
print("- Regional/local names")
print("- Combination drugs")
print("- Veterinary-only drugs")
print("- Very new or obsolete drugs\n")

# Process all antimicrobials with reduced delay
all_antimicrobials = df_antimicrobials['ANTIMICROBIAL'].tolist()
atc_results = get_atc_codes_batch(all_antimicrobials, delay=0.8)  # Slightly faster

print("\n" + "="*50)
print("PROCESSING COMPLETE!")
print("="*50)
found_count = sum(1 for code in atc_results.values() if code is not None)
print(f"ATC codes found: {found_count}/{len(all_antimicrobials)}")
print(f"Success rate: {(found_count/len(all_antimicrobials)*100):.1f}%")
# Out:
# Processing all 392 antimicrobials...
# This will take approximately 8-10 minutes with respectful delays.
# Note: Some antimicrobials may not be found as they might be:
# - Regional/local names
# - Combination drugs
# - Veterinary-only drugs
# - Very new or obsolete drugs
#
# Processing 1/392: 5-Fluorocytosine
#   ✗ Not found
# Processing 2/392: Acetylmidecamycin
#   ✗ Not found
# Processing 3/392: Acetylspiramycin
#   ✗ Not found
# Processing 4/392: Amikacin
#   ✓ Found: D06AX12
# Processing 5/392: Amikacin/Fosfomycin
#   ✓ Found: D06AX12
# Processing 6/392: Amoxicillin
#   ✓ Found: J01CA04
# Processing 7/392: Amoxicillin/Clavulanic acid
#   ✓ Found: J01CA04
# Processing 8/392: Amoxicillin/Sulbactam
#   ✓ Found: J01CA04
# Processing 9/392: Amphotericin B
#   ✓ Found: A01AB04
# Processing 10/392: Ampicillin
#   ✓ Found: J01CA01
# Processing 11/392: Ampicillin/Sulbactam
#   ✓ Found: J01CA01
# Processing 12/392: Amprolium
#   ✗ Not found
# Processing 13/392: Anidulafungin
#   ✓ Found: J02AX06
# Processing 14/392: Apalcillin
#   ✗ Not found
# Processing 15/392: Apramycin
#   ✗ Not found
# Processing 16/392: Arbekacin
#   ✓ Found: J01GB12
# Processing 17/392: Aspoxicillin
#   ✓ Found: J01CA19
# Processing 18/392: Astromicin
#   ✗ Not found
# Processing 19/392: Avibactam
#   ✗ Not found
# Processing 20/392: Avilamycin
#   ✗ Not found
# Processing 21/392: Avoparcin
#   ✗ Not found
# Processing 22/392: Azithromycin
# Error searching for Azithromycin: HTTPSConnectionPool(host='atcddd.fhi.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Azithromycin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D292386B10>, 'Connection to atcddd.fhi.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 23/392: Azlocillin
# Error searching for Azlocillin: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Azlocillin (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D2925A9760>: Failed to resolve 'www.whocc.no' ([Errno 11001] getaddrinfo failed)"))
#   ✗ Not found
# Processing 24/392: Aztreonam
# Error searching for Aztreonam: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Aztreonam (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D291FB8D10>: Failed to resolve 'www.whocc.no' ([Errno 11001] getaddrinfo failed)"))
#   ✗ Not found
# Processing 25/392: Aztreonam/Avibactam
#   ✓ Found: J01DF01
# Processing 26/392: Aztreonam/Nacubactam
#   ✓ Found: J01DF01
# Processing 27/392: Bacampicillin
#   ✓ Found: J01CA06
# Processing 28/392: Bacitracin zinc
#   ✗ Not found
# Processing 29/392: Bedaquiline
#   ✓ Found: J04AK05
# Processing 30/392: Bekanamycin
#   ✓ Found: J01GB13
# Processing 31/392: Besifloxacin
#   ✓ Found: S01AE08
# Processing 32/392: Biapenem
#   ✓ Found: J01DH05
# Processing 33/392: Bicyclomycin
#   ✗ Not found
# Processing 34/392: Brodimoprim
#   ✓ Found: J01EA02
# Processing 35/392: Butoconazole
#   ✓ Found: G01AF15
# Processing 36/392: Cadazolid
#   ✗ Not found
# Processing 37/392: Capreomycin
#   ✓ Found: J04AB30
# Processing 38/392: Carbenicillin
#   ✓ Found: J01CA03
# Processing 39/392: Carumonam
#   ✓ Found: J01DF02
# Processing 40/392: Caspofungin
#   ✓ Found: J02AX04
# Processing 41/392: Cefacetrile
#   ✓ Found: J01DB10
# Processing 42/392: Cefaclor
#   ✓ Found: J01DC04
# Processing 43/392: Cefadroxil
#   ✓ Found: J01DB05
# Processing 44/392: Cefaloridine
#   ✓ Found: J01DB02
# Processing 45/392: Cefamandole
#   ✓ Found: J01DC03
# Processing 46/392: Cefatrizine
#   ✓ Found: J01DB07
# Processing 47/392: Cefazedone
#   ✓ Found: J01DB06
# Processing 48/392: Cefazolin
#   ✓ Found: J01DB04
# Processing 49/392: Cefbuperazone
#   ✓ Found: J01DC13
# Processing 50/392: Cefcapene
#   ✓ Found: J01DD17
# Processing 51/392: Cefcapene pivoxil
#   ✗ Not found
# Processing 52/392: Cefdinir
#   ✓ Found: J01DD15
# Processing 53/392: Cefditoren
#   ✓ Found: J01DD16
# Processing 54/392: Cefditoren pivoxil
#   ✗ Not found
# Processing 55/392: Cefepime
#   ✓ Found: J01DE01
# Processing 56/392: Fluconazole
#   ✓ Found: D01AC15
# Processing 57/392: Flumequine
#   ✓ Found: J01MB07
# Processing 58/392: Fosfluconazole
#   ✗ Not found
# Processing 59/392: Fosfomycin
#   ✓ Found: J01XX01
# Processing 60/392: Fosmidomycin
#   ✗ Not found
# Processing 61/392: Framycetin
#   ✓ Found: D09AA01
# Processing 62/392: Furazolidone
#   ✓ Found: G01AX06
# Processing 63/392: Fusidic acid
#   ✓ Found: D06AX01
# Processing 64/392: Gamithromycin
#   ✗ Not found
# Processing 65/392: Garenoxacin
#   ✓ Found: J01MA19
# Processing 66/392: Gatifloxacin
#   ✓ Found: J01MA16
# Processing 67/392: Gemifloxacin
#   ✓ Found: J01MA15
# Processing 68/392: Gentamicin
#   ✓ Found: D06AX07
# Processing 69/392: Gentamicin-High
#   ✗ Not found
# Processing 70/392: Gepotidacin
#   ✓ Found: J01XX13
# Processing 71/392: Grepafloxacin
#   ✓ Found: J01MA11
# Processing 72/392: Griseofulvin
#   ✓ Found: D01AA08
# Processing 73/392: Habekacin
#   ✗ Not found
# Processing 74/392: Hetacillin
#   ✓ Found: J01CA18
# Processing 75/392: Hygromycin
#   ✗ Not found
# Processing 76/392: Ibrexafungerp
#   ✓ Found: J02AX07
# Processing 77/392: Iclaprim
#   ✓ Found: J01EA03
# Processing 78/392: Imipenem
#   ✓ Found: J01DH51
# Processing 79/392: Imipenem/EDTA
#   ✓ Found: J01DH51
# Processing 80/392: Imipenem/relebactam
#   ✓ Found: J01DH51
# Processing 81/392: Isavuconazole
#   ✓ Found: J02AC05
# Processing 82/392: Isepamicin
#   ✓ Found: J01GB11
# Processing 83/392: Isoconazole
#   ✓ Found: D01AC05
# Processing 84/392: Isoniazid
#   ✓ Found: J04AC01
# Processing 85/392: Itraconazole
#   ✓ Found: J02AC02
# Processing 86/392: Josamycin
#   ✓ Found: J01FA07
# Processing 87/392: Kanamycin
#   ✓ Found: A07AA08
# Processing 88/392: Kanamycin/Cephalexin
#   ✓ Found: A07AA08
# Processing 89/392: Kanamycin-High
#   ✗ Not found
# Processing 90/392: Ketoconazole
#   ✓ Found: D01AC08
# Processing 91/392: Kitasamycin
#   ✗ Not found
# Processing 92/392: Lasalocid
#   ✗ Not found
# Processing 93/392: Lefamulin
#   ✓ Found: J01XX12
# Processing 94/392: Lenampicillin
#   ✗ Not found
# Processing 95/392: Levofloxacin
#   ✓ Found: J01MA12
# Processing 96/392: Levonadifloxacin
#   ✓ Found: J01MA24
# Processing 97/392: Lincomycin
#   ✓ Found: J01FF02
# Processing 98/392: Linco-spectin
#   ✗ Not found
# Processing 99/392: Linezolid
#   ✓ Found: J01XX08
# Processing 100/392: Linoprist-flopristin
#   ✗ Not found
# Processing 101/392: Lomefloxacin
#   ✓ Found: J01MA07
# Processing 102/392: Loracarbef
#   ✓ Found: J01DC08
# Processing 103/392: Manogepix
#   ✗ Not found
# Processing 104/392: Marbofloxacin
#   ✗ Not found
# Processing 105/392: Mecillinam
#   ✓ Found: J01CA11
# Processing 106/392: Meleumycin
#   ✗ Not found
# Processing 107/392: Meropenem
#   ✓ Found: J01DH02
# Processing 108/392: Meropenem/Nacubactam
#   ✓ Found: J01DH02
# Processing 109/392: Meropenem/Vaborbactam
#   ✓ Found: J01DH02
# Processing 110/392: Mesulfamide
#   ✗ Not found
# Processing 111/392: Methicillin
#   ✗ Not found
# Processing 112/392: Metioprim
#   ✗ Not found
# Processing 113/392: Metioxate
#   ✗ Not found
# Processing 114/392: Sulfachlorpyridazine
#   ✗ Not found
# Processing 115/392: Sulfadiazine
#   ✓ Found: J01EC02
# Processing 116/392: Sulfadimethoxine
#   ✓ Found: J01ED01
# Processing 117/392: Sulfadimidine
#   ✓ Found: J01EB03
# Processing 118/392: Sulfamazone
#   ✓ Found: J01ED09
# Processing 119/392: Sulopenem
#   ✗ Not found
# Processing 120/392: Surotomycin
#   ✗ Not found
# Processing 121/392: Talampicillin
#   ✓ Found: J01CA15
# Processing 122/392: Talmetoprim
#   ✗ Not found
# Processing 123/392: Tazobactam
#   ✓ Found: J01CG02
# Processing 124/392: Tebipenem
#   ✓ Found: J01DH06
# Processing 125/392: Tedizolid
#   ✓ Found: J01XX11
# Processing 126/392: Teicoplanin
#   ✓ Found: J01XA02
# Processing 127/392: Teicoplanin-Macromethod
#   ✗ Not found
# Processing 128/392: Telavancin
#   ✓ Found: J01XA03
# Processing 129/392: Telithromycin
#   ✓ Found: J01FA15
# Processing 130/392: Terconazole
#   ✓ Found: G01AG02
# Processing 131/392: Tetracycline
#   ✓ Found: A01AB13
# Processing 132/392: Cefepime/Clavulanic acid
#   ✓ Found: J01DE01
# Processing 133/392: Cefepime/Nacubactam
#   ✓ Found: J01DE01
# Processing 134/392: Cefepime/Tazobactam
#   ✓ Found: J01DE01
# Processing 135/392: Cefepime/Zidebactam
#   ✓ Found: J01DE01
# Processing 136/392: Cefetamet
#   ✓ Found: J01DD10
# Processing 137/392: Cefetamet pivoxil
#   ✗ Not found
# Processing 138/392: Cefetecol
#   ✗ Not found
# Processing 139/392: Cefetrizole
#   ✗ Not found
# Processing 140/392: Cefiderocol
#   ✓ Found: J01DI04
# Processing 141/392: Cefixime
#   ✓ Found: J01DD08
# Processing 142/392: Cefmenoxime
#   ✓ Found: J01DD05
# Processing 143/392: Cefmetazole
#   ✓ Found: J01DC09
# Processing 144/392: Cefminox
#   ✓ Found: J01DC12
# Processing 145/392: Cefodizime
#   ✓ Found: J01DD09
# Processing 146/392: Cefonicid
#   ✓ Found: J01DC06
# Processing 147/392: Cefoperazone
#   ✓ Found: J01DD12
# Processing 148/392: Cefoperazone/Sulbactam
#   ✓ Found: J01DD12
# Processing 149/392: Ceforanide
#   ✓ Found: J01DC11
# Processing 150/392: Cefoselis
#   ✗ Not found
# Processing 151/392: Cefotaxime
#   ✓ Found: J01DD01
# Processing 152/392: Cefotaxime/Clavulanic acid
#   ✓ Found: J01DD01
# Processing 153/392: Cefotaxime/Sulbactam
#   ✓ Found: J01DD01
# Processing 154/392: Cefotetan
#   ✓ Found: J01DC05
# Processing 155/392: Cefotiam
#   ✓ Found: J01DC07
# Processing 156/392: Cefotiam hexetil
#   ✗ Not found
# Processing 157/392: Cefovecin
#   ✗ Not found
# Processing 158/392: Cefoxitin
#   ✓ Found: J01DC01
# Processing 159/392: Cefozopran
#   ✓ Found: J01DE03
# Processing 160/392: Cefpimizole
#   ✗ Not found
# Processing 161/392: Cefpiramide
#   ✓ Found: J01DD11
# Processing 162/392: Cefpirome
#   ✓ Found: J01DE02
# Processing 163/392: Cefpodoxime
#   ✓ Found: J01DD13
# Processing 164/392: Cefpodoxime proxetil
#   ✗ Not found
# Processing 165/392: Cefpodoxime/Clavulanic acid
#   ✓ Found: J01DD13
# Processing 166/392: Cefprozil
#   ✓ Found: J01DC10
# Processing 167/392: Cefquinome
#   ✗ Not found
# Processing 168/392: Cefroxadine
#   ✓ Found: J01DB11
# Processing 169/392: Cefsulodin
#   ✓ Found: J01DD03
# Processing 170/392: Cefsumide
#   ✗ Not found
# Processing 171/392: Ceftaroline
#   ✓ Found: J01DI02
# Processing 172/392: Ceftaroline/Avibactam
#   ✓ Found: J01DI02
# Processing 173/392: Ceftazidime
#   ✓ Found: J01DD02
# Processing 174/392: Ceftazidime/Avibactam
#   ✓ Found: J01DD02
# Processing 175/392: Ceftazidime/Clavulanic acid
#   ✓ Found: J01DD02
# Processing 176/392: Cefteram
#   ✓ Found: J01DD18
# Processing 177/392: Cefteram pivoxil
#   ✗ Not found
# Processing 178/392: Ceftezole
#   ✓ Found: J01DB12
# Processing 179/392: Ceftibuten
#   ✓ Found: J01DD14
# Processing 180/392: Ceftiofur
#   ✗ Not found
# Processing 181/392: Ceftizoxime
#   ✓ Found: J01DD07
# Processing 182/392: Ceftizoxime alapivoxil
#   ✗ Not found
# Processing 183/392: Ceftobiprole
#   ✓ Found: J01DI01
# Processing 184/392: Ceftolozane/Tazobactam
#   ✓ Found: J01DI54
# Processing 185/392: Ceftriaxone
#   ✓ Found: J01DD04
# Processing 186/392: Cefuroxime
#   ✓ Found: J01DC02
# Processing 187/392: Metronidazole
#   ✓ Found: A01AB17
# Processing 188/392: Mezlocillin
#   ✓ Found: J01CA10
# Processing 189/392: Mezlocillin/Sulbactam
#   ✓ Found: J01CA10
# Processing 190/392: Micafungin
#   ✓ Found: J02AX05
# Processing 191/392: Miconazole
#   ✓ Found: A01AB09
# Processing 192/392: Micronomicin
#   ✓ Found: S01AA22
# Processing 193/392: Midecamycin
#   ✓ Found: J01FA03
# Processing 194/392: Miloxacin
#   ✗ Not found
# Processing 195/392: Minocycline
#   ✓ Found: A01AB23
# Processing 196/392: Monensin sodium
#   ✗ Not found
# Processing 197/392: Moxalactam
#   ✗ Not found
# Processing 198/392: Moxifloxacin
#   ✓ Found: J01MA14
# Processing 199/392: Mupirocin
#   ✓ Found: D06AX09
# Processing 200/392: Nacubactam
#   ✗ Not found
# Processing 201/392: Nadifloxacin
#   ✓ Found: D10AF05
# Processing 202/392: Nafcillin
#   ✓ Found: J01CF06
# Processing 203/392: Nafithromycin
#   ✗ Not found
# Processing 204/392: Nalidixic acid
#   ✓ Found: J01MB02
# Processing 205/392: Narasin
#   ✗ Not found
# Processing 206/392: Neomycin
#   ✓ Found: A01AB08
# Processing 207/392: Netilmicin
#   ✓ Found: J01GB07
# Processing 208/392: Nicarbazin
#   ✗ Not found
# Processing 209/392: Nifuroquine
#   ✗ Not found
# Processing 210/392: Nitazoxanide
#   ✓ Found: P01AX11
# Processing 211/392: Nitrofurantoin
#   ✓ Found: J01XE01
# Processing 212/392: Nitrofurazone
#   ✗ Not found
# Processing 213/392: Nitroxoline
#   ✓ Found: J01XX07
# Processing 214/392: Norfloxacin
#   ✓ Found: J01MA06
# Processing 215/392: Norvancomycin
#   ✗ Not found
# Processing 216/392: Novobiocin
#   ✗ Not found
# Processing 217/392: Nystatin
#   ✓ Found: A07AA02
# Processing 218/392: Ofloxacin
#   ✓ Found: J01MA01
# Processing 219/392: Oleandomycin
#   ✓ Found: J01FA05
# Processing 220/392: Omadacycline
#   ✓ Found: J01AA15
# Processing 221/392: Optochin
#   ✗ Not found
# Processing 222/392: Orbifloxacin
#   ✗ Not found
# Processing 223/392: Oritavancin
#   ✓ Found: J01XA05
# Processing 224/392: Ormetroprim/Sulfamethox.
#   ✗ Not found
# Processing 225/392: Ornidazole
#   ✓ Found: G01AF06
# Processing 226/392: Oxacillin
#   ✓ Found: J01CF04
# Processing 227/392: Oxolinic acid
#   ✓ Found: J01MB05
# Processing 228/392: Oxytetracycline
#   ✓ Found: A01AB25
# Processing 229/392: Ozenoxacin
#   ✓ Found: D06AX14
# Processing 230/392: P-Aminosalicylic acid
#   ✗ Not found
# Processing 231/392: Panipenem
#   ✓ Found: J01DH55
# Processing 232/392: Paromomycin
#   ✓ Found: A07AA06
# Processing 233/392: Pazufloxacin
#   ✓ Found: J01MA18
# Processing 234/392: Pefloxacin
#   ✓ Found: J01MA03
# Processing 235/392: Penicillin G
#   ✗ Not found
# Processing 236/392: Penicillin V
#   ✗ Not found
# Processing 237/392: Penicillin/Novobiocin
#   ✓ Found: J01RA01
# Processing 238/392: Penicillin/Sulbactam
#   ✓ Found: J01RA01
# Processing 239/392: Pentisomicin
#   ✗ Not found
# Processing 240/392: Pipemidic acid
#   ✓ Found: J01MB04
# Processing 241/392: Piperacillin
#   ✓ Found: J01CA12
# Processing 242/392: Piperacillin/Sulbactam
#   ✓ Found: J01CA12
# Processing 243/392: Piperacillin/Tazobactam
#   ✓ Found: J01CA12
# Processing 244/392: Pentizidone
#   ✗ Not found
# Processing 245/392: Terbinafine
#   ✓ Found: D01AE15
# Processing 246/392: Temafloxacin
#   ✓ Found: J01MA05
# Processing 247/392: Temocillin
#   ✓ Found: J01CA17
# Processing 248/392: Tetroxoprim
#   ✗ Not found
# Processing 249/392: Thiacetazone
#   ✗ Not found
# Processing 250/392: Thiamphenicol
#   ✓ Found: J01BA02
# Processing 251/392: Tiamulin
#   ✗ Not found
# Processing 252/392: Ticarcillin
#   ✓ Found: J01CA13
# Processing 253/392: Ticarcillin/Clavulanic acid
#   ✓ Found: J01CA13
# Processing 254/392: Tigecycline
#   ✓ Found: J01AA12
# Processing 255/392: Tilbroquinol
#   ✓ Found: P01AA05
# Processing 256/392: Tildipirosin
#   ✗ Not found
# Processing 257/392: Tilmicosin
#   ✗ Not found
# Processing 258/392: Tinidazole
#   ✓ Found: G01AF21
# Processing 259/392: Tiodonium chloride
#   ✗ Not found
# Processing 260/392: Tioxacin
#   ✗ Not found
# Processing 261/392: Trovafloxacin
#   ✓ Found: J01MA13
# Processing 262/392: Trospectomycin
#   ✗ Not found
# Processing 263/392: Cefuroxime axetil
#   ✗ Not found
# Processing 264/392: Cefuzonam
#   ✗ Not found
# Processing 265/392: Cephalexin
#   ✗ Not found
# Processing 266/392: Cephalothin
#   ✗ Not found
# Processing 267/392: Cephapirin
#   ✗ Not found
# Processing 268/392: Cephradine
#   ✗ Not found
# Processing 269/392: Cetocycline
#   ✗ Not found
# Processing 270/392: Chloramphenicol
#   ✓ Found: D06AX02
# Processing 271/392: Chlortetracycline
#   ✓ Found: A01AB21
# Processing 272/392: Ciclacillin
#   ✗ Not found
# Processing 273/392: Cinoxacin
#   ✓ Found: J01MB06
# Processing 274/392: Ciprofloxacin
#   ✓ Found: J01MA02
# Processing 275/392: Clarithromycin
#   ✓ Found: J01FA09
# Processing 276/392: Clavulanic acid
#   ✗ Not found
# Processing 277/392: Clinafloxacin
#   ✗ Not found
# Processing 278/392: Clindamycin
#   ✓ Found: D10AF01
# Processing 279/392: Clofazimine
#   ✓ Found: J04BA01
# Processing 280/392: Clotrimazole
#   ✓ Found: A01AB18
# Processing 281/392: Cloxacillin
#   ✓ Found: J01CF02
# Processing 282/392: Colistin
# Error searching for Colistin: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Colistin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D292764110>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 283/392: Colistin/Polysorbate
# Error searching for Colistin/Polysorbate: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Colistin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2923569F0>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 284/392: Cycloserine
#   ✓ Found: J04AB01
# Processing 285/392: Dalbavancin
#   ✓ Found: J01XA04
# Processing 286/392: Danofloxacin
#   ✗ Not found
# Processing 287/392: Daptomycin
#   ✓ Found: J01XX09
# Processing 288/392: Delafloxacin
# Error searching for Delafloxacin: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Delafloxacin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D292354D40>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 289/392: Delamanid
#   ✓ Found: J04AK06
# Processing 290/392: Demeclocycline
#   ✓ Found: D06AA01
# Processing 291/392: Dibekacin
#   ✓ Found: J01GB09
# Processing 292/392: Dicloxacillin
#   ✓ Found: J01CF01
# Processing 293/392: Difloxacin
#   ✗ Not found
# Processing 294/392: Dirithromycin
#   ✓ Found: J01FA13
# Processing 295/392: Doripenem
#   ✓ Found: J01DH04
# Processing 296/392: Doxycycline
#   ✓ Found: A01AB22
# Processing 297/392: Econazole
#   ✓ Found: D01AC03
# Processing 298/392: Enoxacin
#   ✓ Found: J01MA04
# Processing 299/392: Enrofloxacin
#   ✗ Not found
# Processing 300/392: Enviomycin
# Error searching for Enviomycin: HTTPSConnectionPool(host='atcddd.fhi.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Enviomycin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D291C1BE00>, 'Connection to atcddd.fhi.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 301/392: Eperozolid
# Error searching for Eperozolid: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Eperozolid (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2927A5700>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 302/392: Epiroprim
# Error searching for Epiroprim: HTTPSConnectionPool(host='www.whocc.no', port=443): Read timed out. (read timeout=10)
#   ✗ Not found
# Processing 303/392: Eravacycline
#   ✓ Found: J01AA13
# Processing 304/392: Ertapenem
#   ✓ Found: J01DH03
# Processing 305/392: Erythromycin
#   ✓ Found: D10AF02
# Processing 306/392: Ethambutol
#   ✓ Found: J04AK02
# Processing 307/392: Ethionamide
#   ✓ Found: J04AD03
# Processing 308/392: Ethopabate
#   ✗ Not found
# Processing 309/392: Exebacase
#   ✗ Not found
# Processing 310/392: Faropenem
#   ✓ Found: J01DI03
# Processing 311/392: Fidaxomicin
#   ✓ Found: A07AA12
# Processing 312/392: Finafloxacin
#   ✗ Not found
# Processing 313/392: Flavomycin
#   ✗ Not found
# Processing 314/392: Fleroxacin
#   ✓ Found: J01MA08
# Processing 315/392: Flomoxef
#   ✓ Found: J01DC14
# Processing 316/392: Florfenicol
#   ✗ Not found
# Processing 317/392: Flucloxacillin
#   ✓ Found: J01CF05
# Processing 318/392: Pexiganan
#   ✗ Not found
# Processing 319/392: Phenethicillin
#   ✗ Not found
# Processing 320/392: Pimaricin
#   ✗ Not found
# Processing 321/392: Piridicillin
#   ✗ Not found
# Processing 322/392: Pirlimycin
#   ✗ Not found
# Processing 323/392: Piromidic acid
#   ✓ Found: J01MB03
# Processing 324/392: Pivmecillinam
#   ✓ Found: J01CA08
# Processing 325/392: Plazomicin
#   ✓ Found: J01GB14
# Processing 326/392: Polymyxin B
#   ✓ Found: A07AA05
# Processing 327/392: Polymyxin B/Polysorbate 80
#   ✓ Found: A07AA05
# Processing 328/392: Posaconazole
#   ✓ Found: J02AC04
# Processing 329/392: Pradofloxacin
#   ✗ Not found
# Processing 330/392: Premafloxacin
#   ✗ Not found
# Processing 331/392: Primycin
#   ✗ Not found
# Processing 332/392: Pristinamycin
#   ✓ Found: J01FG01
# Processing 333/392: Propicillin
#   ✓ Found: J01CE03
# Processing 334/392: Propikacin
#   ✗ Not found
# Processing 335/392: Prothionamide
#   ✗ Not found
# Processing 336/392: Prulifloxacin
#   ✓ Found: J01MA17
# Processing 337/392: Pyrazinamide
#   ✓ Found: J04AK01
# Processing 338/392: Quinupristin/Dalfopristin
#   ✓ Found: J01FG02
# Processing 339/392: Ractopamine
#   ✗ Not found
# Processing 340/392: Ramoplanin
#   ✗ Not found
# Processing 341/392: Razupenem
#   ✗ Not found
# Processing 342/392: Retapamulin
#   ✓ Found: D06AX13
# Processing 343/392: Rezafungin
#   ✓ Found: J02AX08
# Processing 344/392: Ribostamycin
#   ✓ Found: J01GB10
# Processing 345/392: Ridinilazole
#   ✗ Not found
# Processing 346/392: Rifabutin
#   ✓ Found: J04AB04
# Processing 347/392: Rifampin
#   ✗ Not found
# Processing 348/392: Rifapentine
#   ✓ Found: J04AB05
# Processing 349/392: Rifaximin
#   ✓ Found: A07AA11
# Processing 350/392: Ritipenem
#   ✗ Not found
# Processing 351/392: Ritipenem acoxil
#   ✗ Not found
# Processing 352/392: Rokitamycin
#   ✓ Found: J01FA12
# Processing 353/392: Rosoxacin
#   ✓ Found: J01MB01
# Processing 354/392: Roxithromicin
#   ✗ Not found
# Processing 355/392: Salinomycin
#   ✗ Not found
# Processing 356/392: Sarafloxacin
#   ✗ Not found
# Processing 357/392: Sarmoxicillin
#   ✗ Not found
# Processing 358/392: Secnidazole
#   ✓ Found: P01AB07
# Processing 359/392: Sisomicin
#   ✓ Found: J01GB08
# Processing 360/392: Sitafloxacin
#   ✓ Found: J01MA21
# Processing 361/392: Solithromycin
#   ✓ Found: J01FA16
# Processing 362/392: Sparfloxacin
#   ✓ Found: J01MA09
# Processing 363/392: Spectinomycin
#   ✓ Found: J01XX04
# Processing 364/392: Spiramycin
#   ✓ Found: J01FA02
# Processing 365/392: Streptomycin
#   ✓ Found: A07AA04
# Processing 366/392: Streptomycin-High
#   ✗ Not found
# Processing 367/392: Sulbactam
#   ✓ Found: J01CG01
# Processing 368/392: Sulbenicillin
#   ✓ Found: J01CA16
# Processing 369/392: Sulconazole
#   ✓ Found: D01AC09
# Processing 370/392: Sulfamethazine
#   ✗ Not found
# Processing 371/392: Sulfamethoxazole
#   ✓ Found: J01EC01
# Processing 372/392: Sulfasuccinamide
#   ✗ Not found
# Processing 373/392: Sulfathiazole
#   ✓ Found: D06BA02
# Processing 374/392: Sulfisoxazole
#   ✗ Not found
# Processing 375/392: Sulfonamides
#   ✓ Found: J01RA02
# Processing 376/392: Tulathromycin
#   ✗ Not found
# Processing 377/392: Tizoxanide
#   ✗ Not found
# Processing 378/392: Tobramycin
#   ✓ Found: J01GB01
# Processing 379/392: Tosufloxacin
#   ✓ Found: J01MA22
# Processing 380/392: Trimethoprim
#   ✓ Found: J01EA01
# Processing 381/392: Trimethoprim/Sulfamethox.
#   ✓ Found: J01EA01
# Processing 382/392: Troleandomycin
#   ✓ Found: J01FA08
# Processing 383/392: Tylosin
#   ✗ Not found
# Processing 384/392: Tylvalosin
#   ✗ Not found
# Processing 385/392: Ulifloxacin
# Error searching for Ulifloxacin: HTTPSConnectionPool(host='atcddd.fhi.no', port=443): Read timed out. (read timeout=10)
#   ✗ Not found
# Processing 386/392: Vancomycin
# Error searching for Vancomycin: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Vancomycin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D292608230>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 387/392: Vancomycin-Macromethod
# Error searching for Vancomycin-Macromethod: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=VancomycinMacromethod (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2928E8860>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 388/392: Viomycin
# Error searching for Viomycin: HTTPSConnectionPool(host='www.whocc.no', port=443): Max retries exceeded with url: /atc_ddd_index/?code=&name=Viomycin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D29230B2F0>, 'Connection to www.whocc.no timed out. (connect timeout=10)'))
#   ✗ Not found
# Processing 389/392: Virginiamycine
#   ✗ Not found
# Processing 390/392: Voriconazole
#   ✓ Found: J02AC03
# Processing 391/392: Zidebactam
#   ✗ Not found
# Processing 392/392: Zoliflodacin
#   ✗ Not found
#
# ==================================================
# PROCESSING COMPLETE!
# ==================================================
# ATC codes found: 250/392
# Success rate: 63.8%

# %%
# Create the final dataframe with ATC codes
df_antimicrobials_withATC = df_antimicrobials.copy()

# Map the ATC codes to the dataframe
df_antimicrobials_withATC['ATC_CODE'] = df_antimicrobials_withATC['ANTIMICROBIAL'].map(atc_results)

# Display summary
print("\n=== FINAL RESULTS ===")
print(f"Total antimicrobials: {len(df_antimicrobials_withATC)}")
print(f"ATC codes found: {df_antimicrobials_withATC['ATC_CODE'].notna().sum()}")
print(f"ATC codes missing: {df_antimicrobials_withATC['ATC_CODE'].isna().sum()}")
print(f"Success rate: {(df_antimicrobials_withATC['ATC_CODE'].notna().sum() / len(df_antimicrobials_withATC) * 100):.1f}%")

# Show sample of results
print("\nSample of results with ATC codes:")
sample_with_atc = df_antimicrobials_withATC[df_antimicrobials_withATC['ATC_CODE'].notna()].head(10)
print(sample_with_atc[['WHONET_CODE', 'ANTIMICROBIAL', 'ATC_CODE']].to_string(index=False))

# Show the final dataframe structure
print("\nFinal dataframe structure:")
print(df_antimicrobials_withATC.info())

# %%
# Save the results to Excel file
output_file = r'C:\Personal_Projects\Astro\project_resources\Antimicrobials_with_ATC.xlsx'
df_antimicrobials_withATC.to_excel(output_file, index=False)
print(f"\nResults saved to: {output_file}")

# Also save as CSV for easier viewing
csv_file = r'C:\Personal_Projects\Astro\project_resources\Antimicrobials_with_ATC.csv'
df_antimicrobials_withATC.to_csv(csv_file, index=False)
print(f"Results also saved as CSV: {csv_file}")

print("\n🎉 Task completed successfully!")
print(f"Final dataframe 'df_antimicrobials_withATC' contains {len(df_antimicrobials_withATC)} rows with ATC codes populated where found.")

# %%
# Analyze ATC code patterns
print("\n=== ATC CODE PATTERNS ANALYSIS ===")

# Get all found ATC codes
found_atc_codes = df_antimicrobials_withATC['ATC_CODE'].dropna()

if len(found_atc_codes) > 0:
    # Analyze ATC code prefixes (first character indicates main anatomical group)
    atc_groups = found_atc_codes.str[0].value_counts()
    print("ATC Main Groups found:")
    for group, count in atc_groups.items():
        group_name = {
            'A': 'Alimentary tract and metabolism',
            'B': 'Blood and blood forming organs', 
            'C': 'Cardiovascular system',
            'D': 'Dermatologicals',
            'G': 'Genitourinary system and sex hormones',
            'H': 'Systemic hormonal preparations',
            'J': 'Antiinfectives for systemic use',
            'L': 'Antineoplastic and immunomodulating agents',
            'M': 'Musculo-skeletal system',
            'N': 'Nervous system',
            'P': 'Antiparasitic products',
            'R': 'Respiratory system',
            'S': 'Sensory organs',
            'V': 'Various'
        }.get(group, 'Unknown')
        print(f"  {group}: {count} codes ({group_name})")
    
    print(f"\nMost common ATC codes:")
    print(found_atc_codes.value_counts().head(10))
else:
    print("No ATC codes found to analyze.")

# %%
# Create a list of antimicrobials that need manual lookup
missing_atc = df_antimicrobials_withATC[df_antimicrobials_withATC['ATC_CODE'].isna()]

if len(missing_atc) > 0:
    print(f"\n=== ANTIMICROBIALS NEEDING MANUAL LOOKUP ({len(missing_atc)} items) ===")
    print("These antimicrobials were not found automatically and may need manual research:")
    
    # Show first 15 missing ones
    print("\nSample of missing antimicrobials:")
    for i, row in missing_atc.head(15).iterrows():
        print(f"- {row['ANTIMICROBIAL']} (WHONET: {row['WHONET_CODE']})")
    
    if len(missing_atc) > 15:
        print(f"... and {len(missing_atc) - 15} more")
    
    # Save missing list to file for manual research
    missing_file = r'C:\Personal_Projects\Astro\project_resources\Antimicrobials_missing_ATC.csv'
    missing_atc.to_csv(missing_file, index=False)
    print(f"\nComplete missing list saved to: {missing_file}")
else:
    print("\n🎉 All antimicrobials found ATC codes!")

print("\n" + "="*60)
print("TASK COMPLETION SUMMARY")
print("="*60)
print(f"✅ Processed {len(df_antimicrobials)} antimicrobials")
print(f"✅ Found {df_antimicrobials_withATC['ATC_CODE'].notna().sum()} ATC codes ({(df_antimicrobials_withATC['ATC_CODE'].notna().sum() / len(df_antimicrobials_withATC) * 100):.1f}% success rate)")
print(f"✅ Created df_antimicrobials_withATC dataframe")
print(f"✅ Saved results to Excel and CSV files")
print(f"✅ Identified {len(missing_atc)} antimicrobials needing manual lookup")
print("\n📈 The df_antimicrobials_withATC dataframe is ready for use!")
print("\nFinal dataframe shape:", df_antimicrobials_withATC.shape)
print("Columns:", list(df_antimicrobials_withATC.columns))
